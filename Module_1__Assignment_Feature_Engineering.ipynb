# %% [markdown]
# #Theory Questions and Answers
#
# 1.  What is a parameter?
#   - A parameter is a variable inside a model that is learned from the data during training.
#
#   - Example: In a linear regression model 𝑦=𝑚𝑥+𝑐,
#   - 𝑚(slope) and 𝑐 (intercept) are parameters.
#
# 2.  What is correlation?
#   - Correlation measures the strength and direction of the relationship between two variables.
#
#   - Value ranges from -1 to +1.
#   - +1: Strong positive relation
#   - −1: Strong negative relation
#   - 0: No relation
#
# What does negative correlation mean?
#   - When one variable increases, the other decreases.
#
#   - Example: Number of hours playing video games  vs exam scores.
#
# 3.  Define Machine Learning. What are the main components in Machine Learning?
#   - Machine Learning: A field of AI where systems learn patterns from data without being explicitly programmed.
#
#   - Main components:
#
#     - Data (input)
#
#     - Features (variables describing data)
#
#     - Model (algorithm)
#
#     - Loss function (error measure)
#
#     - Optimizer (improves model parameters)
#
# 4. How does loss value help in determining whether the model is good or not?
#   - Loss value tells how far predictions are from actual values.
#
#   - Lower loss = better model.
#
#   - If loss doesn’t decrease after training → model may be underfitting or overfitting.
#
# 5.  What are continuous and categorical variables?
#   - Continuous: Numeric values with infinite possibilities (e.g., height, temperature).
#
#   - Categorical: Discrete categories (e.g., gender = Male/Female).
#
# 6.   How do we handle categorical variables in Machine Learning? What are the common techniques?
#   - Label Encoding → Assigns integer values (Male = 0, Female = 1).
#
#   - One-Hot Encoding → Creates binary columns (Gender_Male, Gender_Female).
#
#   - Target Encoding → Replace category with mean of target variable.
#
# 7.  What do you mean by training and testing a dataset?
#   - Training dataset → used to train model.
#
#   - Testing dataset → used to evaluate model performance on unseen data.
#
# 8. What is sklearn.preprocessing?
#   - A module in scikit-learn containing preprocessing functions like:
#
#   - Scaling (StandardScaler)
#
#   - Encoding (LabelEncoder, OneHotEncoder)
#
#   - Normalization
#
# 9. What is a Test set?
#   - A portion of data kept aside to test the performance of the trained model.
#
# 10. How do we split data for model fitting (training and testing) in Python?
#   - We divide the dataset into two parts:
#
#   - Training set → used to train the model (usually 70–80% of data)
#
#   - Testing set → used to evaluate performance (20–30% of data)
#
#   - This ensures the model generalizes well to unseen data.
#   - Example code:
#
#
#             from sklearn.model_selection import train_test_split
#             X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#
# How do you approach a Machine Learning problem?
#
#   - Step 1: Understand the problem (classification/regression/clustering).
#
#   -Step 2: Collect and clean data (handle missing values, outliers).
#
#   - Step 3: Perform EDA (visualize, check distributions, correlations).
#
#   - Step 4: Preprocess (scaling, encoding categorical variables).
#
#   - Step 5: Split data into train/test sets.
#
#   - Step 6: Select appropriate model(s).
#
#   - Step 7: Train model and evaluate performance (metrics like accuracy, RMSE, etc.).
#
#   - Step 8: Perform hyperparameter tuning.
#
#   - Step 9: Test final model on unseen data.
#
# 11. Why do we have to perform EDA before fitting a model to the data?
#   - EDA helps to:
#
#     - Understand patterns
#
#     - Detect missing/outlier values
#
#     - Choose correct preprocessing & model
#
# 12. What is correlation?
#   - Correlation measures the strength and direction of the relationship between two variables.
#
#   - Range: -1 to +1.
#   - +1: Perfect positive relation
#   - 0: No relation
#   - −1: Perfect negative relation
#
# 13. What does negative correlation mean?
#   - As one variable increases, the other decreases.
#
#   - Example: Number of hours watching TV vs exam scores.
#
# 14.  How can you find correlation between variables in Python?
#   - In Python, we use pandas.DataFrame.corr() to find correlation between variables.
#   - Example:
#
#               df.corr()
# 15. What is causation? Explain difference between correlation and causation with an example.
#   - Causation: One variable directly affects another.
#
#   - Correlation: Two variables move together but not due to a cause-effect relationship.
#
#   - Example: Ice cream sales and drowning cases are correlated (both rise in summer), but ice cream does not cause drowning. The actual cause is temperature.
#
# 16.  What is an Optimizer? What are different types of optimizers? Explain each with an example.
#   - An optimizer is an algorithm that adjusts model parameters to minimize the loss function.
#
#   - Gradient Descent: Updates parameters step by step.
#
#   - SGD (Stochastic Gradient Descent): Updates using random data batches.
#
#   - Adam: Combines momentum and adaptive learning rate.
#
#   - RMSProp: Adapts learning rate for each parameter.
#
# 17.  What is sklearn.linear_model?
#   - It is a module in scikit-learn that provides linear models such as LinearRegression, LogisticRegression, Ridge, and Lasso.
#
# 18. What does model.fit() do? What arguments must be given?
#   - fit() trains the model on training data.
#
#   - Required arguments: features (X) and labels (y).
#   - Example:
#
#
#             model.fit(X_train, y_train)
#
# 19. What does model.predict() do? What arguments must be given?
#   - predict() generates predictions for new/unseen data.
#
#   - Required argument: features (X).
#   - Example:
#
#             model.predict(X_test)
# 20. What are continuous and categorical variables?
#   - Continuous variables: Numeric values with infinite possibilities (e.g., height, weight).
#
#   - Categorical variables: Discrete categories (e.g., gender, city, blood group).
#
# 21.  What is feature scaling? How does it help in Machine Learning?
#   - Feature scaling standardizes or normalizes data so that all features lie in the same range.
#   - It helps prevent bias toward variables with large values and speeds up training.
#
# 22.  How do we perform scaling in Python?
#   - We use scalers from sklearn such as StandardScaler or MinMaxScaler.
#
#   - Example:
#
#             from sklearn.preprocessing import StandardScaler
#             scaler = StandardScaler()
#             X_scaled = scaler.fit_transform(X)
# 23. What is sklearn.preprocessing?
#   - It is a module in scikit-learn that provides functions for:
#
#   - Scaling (StandardScaler, MinMaxScaler)
#
#   - Encoding (LabelEncoder, OneHotEncoder)
#
#   - Normalization
#
# 24. How do we split data for model fitting (training and testing) in Python?
#   - We split the dataset into training and testing parts using train_test_split.
#   - Example:
#
#             from sklearn.model_selection import train_test_split
#             X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# 25. Explain data encoding?
#   - Data encoding converts categorical values into numeric form so machine learning models can process them.
#
#   - Label Encoding: Converts categories into numbers (Male=0, Female=1).
#
#   - One-Hot Encoding: Creates separate binary columns for each category.
#
#   - Target Encoding: Replaces category with average target value.
